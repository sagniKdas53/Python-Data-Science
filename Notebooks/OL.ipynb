# %%
import random as R

# %%
one = R.getstate()
one
# Out:
# (3,
#  (2147483648,
#   3440788084,
#   2138240092,
#   942445869,
#   2414748870,
#   2794872986,
#   1317149740,
#   3856740640,
#   3487843386,
#   302185743,
#   475097426,
#   544032793,
#   19443652,
#   974506030,
#   3021656740,
#   3409835083,
#   2182224971,
#   2831522252,
#   868065025,
#   1847589969,
#   2938905655,
#   2775500202,
#   1471788281,
#   869600691,
#   2526054507,
#   454455397,
#   1030410415,
#   491718600,
#   3187228565,
#   193699628,
#   2981974272,
#   1508998601,
#   2042480720,
#   3615627554,
#   386846543,
#   3040116010,
#   140170783,
#   15675745,
#   3738224977,
#   1132949118,
#   3540974029,
#   1526407585,
#   4231896104,
#   3415363864,
#   1309269317,
#   2862111429,
#   708682660,
#   697570059,
#   1982536169,
#   2433955186,
#   4186501673,
#   2827579012,
#   3451393037,
#   362647342,
#   2311013167,
#   2258157473,
#   122830612,
#   2372974384,
#   3496150914,
#   1446540187,
#   2195377118,
#   1380972988,
#   3190014885,
# ...

# %%
R.seed()

# %%
two = R.getstate()
two
# Out:
# (3,
#  (2147483648,
#   1219512264,
#   2609859704,
#   3225209025,
#   1312539499,
#   1206706410,
#   537575649,
#   365022771,
#   2551805549,
#   406144248,
#   142179887,
#   117106072,
#   166045877,
#   3150025859,
#   2750185336,
#   1465027387,
#   142932080,
#   4270458637,
#   2854714121,
#   2794068473,
#   4219343659,
#   3572170143,
#   1741343071,
#   1518591390,
#   1467945009,
#   2225078493,
#   3113164219,
#   527414029,
#   3706421193,
#   3445302437,
#   3740738789,
#   3052450172,
#   1016011522,
#   361711855,
#   1947079220,
#   3603635039,
#   2478398234,
#   94955873,
#   2331642693,
#   3006069825,
#   1127256114,
#   287753064,
#   2984573580,
#   3256874909,
#   2575109247,
#   3591201910,
#   1783278971,
#   2540638451,
#   2152344561,
#   1493442042,
#   2346462734,
#   1691022162,
#   616841856,
#   1336834896,
#   516146259,
#   3887461275,
#   3824879155,
#   3390845447,
#   20744346,
#   1491592080,
#   1348690961,
#   3570854984,
#   3607534317,
# ...

# %%
one == two
# Out:
# False

# %%
#R.seed(10,2)
three = R.getstate()
three
# Out:
# (3,
#  (2147483648,
#   1219512264,
#   2609859704,
#   3225209025,
#   1312539499,
#   1206706410,
#   537575649,
#   365022771,
#   2551805549,
#   406144248,
#   142179887,
#   117106072,
#   166045877,
#   3150025859,
#   2750185336,
#   1465027387,
#   142932080,
#   4270458637,
#   2854714121,
#   2794068473,
#   4219343659,
#   3572170143,
#   1741343071,
#   1518591390,
#   1467945009,
#   2225078493,
#   3113164219,
#   527414029,
#   3706421193,
#   3445302437,
#   3740738789,
#   3052450172,
#   1016011522,
#   361711855,
#   1947079220,
#   3603635039,
#   2478398234,
#   94955873,
#   2331642693,
#   3006069825,
#   1127256114,
#   287753064,
#   2984573580,
#   3256874909,
#   2575109247,
#   3591201910,
#   1783278971,
#   2540638451,
#   2152344561,
#   1493442042,
#   2346462734,
#   1691022162,
#   616841856,
#   1336834896,
#   516146259,
#   3887461275,
#   3824879155,
#   3390845447,
#   20744346,
#   1491592080,
#   1348690961,
#   3570854984,
#   3607534317,
# ...

# %%
two == three
# Out:
# True

# %%
R.seed('sagnik',2)
sagnik = R.getstate()

# %%
sagnik
# Out:
# (3,
#  (2147483648,
#   1137679971,
#   812455050,
#   2986201984,
#   3728160214,
#   4240338747,
#   3283933052,
#   695230425,
#   2710884223,
#   3896260286,
#   3147383550,
#   2554926470,
#   1384629817,
#   530939989,
#   1037639777,
#   3757058032,
#   2863249283,
#   1331617229,
#   3566081538,
#   2600713898,
#   141392924,
#   3847245,
#   694384989,
#   3846631173,
#   2537830094,
#   2106747320,
#   2068154511,
#   997242176,
#   2055849295,
#   3695567506,
#   1013885667,
#   1305402216,
#   4131928560,
#   594503748,
#   600910137,
#   446284040,
#   1537779963,
#   2101212967,
#   1739352645,
#   1425348181,
#   2393475724,
#   2205252399,
#   2436715352,
#   1696427724,
#   3110485725,
#   1064481140,
#   1465701227,
#   195792061,
#   4170037400,
#   894186419,
#   3576222945,
#   3421901713,
#   2905092741,
#   2751016032,
#   1998042119,
#   2901830053,
#   2224232822,
#   4201185757,
#   148962114,
#   2080326941,
#   699435376,
#   1560667576,
#   976297836,
# ...

# %%
nextG = R.getstate()
nextG == sagnik
# Out:
# True

# %%
import os
seeds = os.urandom(8)

# %%
seeds
reseed = R.seed(seeds,2)

# %%
reseed == R.seed(seeds,2)
# Out:
# True

# %%
#sysSeed = R.SystemRandom()
#sysSeed

# %%
sysSeed = R.SystemRandom(seeds)
sysSeed

# %%
reseed == R.getstate()
# Out:
# False
