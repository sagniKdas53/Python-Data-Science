# %%
arr = [1,2,3,4]
arr
# Out:
# [1, 2, 3, 4]

# %%
from array import *
arrIter  = array('i',arr)
arrIter
# Out:
# array('i', [1, 2, 3, 4])

# %%
print(arrIter)
# Out:
# array('i', [1, 2, 3, 4])

# %%
tup = (7,8,6)
tup
# Out:
# (7, 8, 6)

# %%
tupp = 5, 6 ,9
tupp
# Out:
# (5, 6, 9)

# %%
typeo = type(tupp),type(tup)
typeo
# Out:
# (tuple, tuple)

# %%
import random as R
import os
import sys

# %%
getRand = os.urandom(4)
getRand
# Out:
# b'\xc7\xc9\x03\xe0'

# %%
rand=int.from_bytes(os.urandom(4), sys.byteorder)
rand
# Out:
# 3127081595

# %%
R.seed(getRand,2)

# %%
state = R.getstate()

# %%
state
# Out:
# (3,
#  (2147483648,
#   962942202,
#   2309619256,
#   214158328,
#   446953253,
#   1924747094,
#   577860675,
#   1649984717,
#   518632480,
#   1463224807,
#   1719196984,
#   2632546221,
#   947231745,
#   3513544515,
#   578586569,
#   3644012548,
#   337363619,
#   689374650,
#   2721104816,
#   3013184515,
#   465684476,
#   2225699361,
#   3676853361,
#   3226233619,
#   197455504,
#   4256483932,
#   2304823128,
#   3674933869,
#   1465943647,
#   2960299567,
#   1202966294,
#   2100621222,
#   2413273128,
#   4260384758,
#   1605566596,
#   651454277,
#   2650058821,
#   3300196961,
#   2135028474,
#   4114205229,
#   3417905578,
#   3991269561,
#   3840549258,
#   4072458954,
#   1498003134,
#   802103952,
#   1332905834,
#   2332300883,
#   112980836,
#   3910944697,
#   41838417,
#   1904240653,
#   485625131,
#   2936639815,
#   3862275232,
#   1081508674,
#   3430830839,
#   4255476916,
#   4196530362,
#   4285235778,
#   864961018,
#   4195203496,
#   1285992272,
# ...

# %%
import secrets

# %%
listR = [R.randint(9,99) for x in range(0,R.randint(9,99))]

# %%
listR
# Out:
# [31,
#  75,
#  12,
#  63,
#  27,
#  63,
#  69,
#  90,
#  74,
#  49,
#  41,
#  48,
#  17,
#  71,
#  24,
#  22,
#  94,
#  16,
#  66,
#  82,
#  75]

# %%
R.SystemRandom()

# %%
R.getstate()
# Out:
# (3,
#  (2147483648,
#   962942202,
#   2309619256,
#   214158328,
#   446953253,
#   1924747094,
#   577860675,
#   1649984717,
#   518632480,
#   1463224807,
#   1719196984,
#   2632546221,
#   947231745,
#   3513544515,
#   578586569,
#   3644012548,
#   337363619,
#   689374650,
#   2721104816,
#   3013184515,
#   465684476,
#   2225699361,
#   3676853361,
#   3226233619,
#   197455504,
#   4256483932,
#   2304823128,
#   3674933869,
#   1465943647,
#   2960299567,
#   1202966294,
#   2100621222,
#   2413273128,
#   4260384758,
#   1605566596,
#   651454277,
#   2650058821,
#   3300196961,
#   2135028474,
#   4114205229,
#   3417905578,
#   3991269561,
#   3840549258,
#   4072458954,
#   1498003134,
#   802103952,
#   1332905834,
#   2332300883,
#   112980836,
#   3910944697,
#   41838417,
#   1904240653,
#   485625131,
#   2936639815,
#   3862275232,
#   1081508674,
#   3430830839,
#   4255476916,
#   4196530362,
#   4285235778,
#   864961018,
#   4195203496,
#   1285992272,
# ...
